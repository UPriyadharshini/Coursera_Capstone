# %% [markdown]
# # Clustering of Toronto Neighbourhood

# %% [markdown]
# This notebook contains the work for clustering Toronto neighbourhood

# %% [markdown]
# ## Part I: Process and Clean Data

# %% [markdown]
# We first import the required libraries. The library 'requests' for handling html page requests, the library 'lxml' for processing the html page and the pandas library for handling data

# %%
import requests
import lxml.html as lh
import pandas as pd

# %% [markdown]
# Request the html page from wikipedia which lists the postal codes of cananda

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
doc = lh.fromstring(page.content)

# %% [markdown]
# Process the table which contains the postal code. The table is identified as the one where the 'class' attirbute is set to 'wikitable sortable' as there is only one table with that attribute.

# %%
table_one_elements=doc.xpath('//table[@class="wikitable sortable"]/tbody/tr')
table_one_elements_len = len(table_one_elements)

# %% [markdown]
# Extract the table header

# %%
table_header=[]
for col in table_one_elements[0].iterchildren():
    table_header.append(col.text_content().strip())

# %% [markdown]
# Extract the table data in python dictionary format with the key being postal code. For each row, check that there are three columns and if the row does not contain 3 columns, do not process (as we dont know how to process it). For each processed row, check the column 2 (borough). If not assigned, skip the row. If entry for borough is defined for the row, then check if the postal code already exists in dictionary. If yes, then append the neighbourhood defined for the current row to the neighbourhood already definded for the postal code in the dictionary. Else, create a new entry for the postal code with the borough and neighbourhood defined for the current row. If the neighbourhood is not defined for the current row, then take borough as the neighbourhood

# %%
table_data={}
for row in range(1,table_one_elements_len):
    row_content = table_one_elements[row]
    row_content_len = len(row_content)
  
  
    if row_content_len == 3:
        borough = row_content[1].text_content()
        if borough != 'Not assigned':
                
            postcode = row_content[0].text_content()            
            if postcode in table_data.keys():
      
                neighbourhood = row_content[2].text_content().strip()
                if neighbourhood == 'Not assigned':
                    neighbourhood = borough
                     
                old_neighbourhood = table_data[postcode][1]  
                new_neighbourhood = old_neighbourhood + ", " + neighbourhood
                attr = [borough, new_neighbourhood]
                    
            else:
                    
                neighbourhood = row_content[2].text_content().strip()    
                attr = [borough, neighbourhood]
                
            table_data[postcode] = attr      
                
    else:
        pass

# %% [markdown]
# Convert the dictionary into pandas data frame. Reset the index and rename the index colum to html table header[0] (extracted in earlier step). Print the data frame and check if the data frame looks good

# %%
df=pd.DataFrame.from_dict(table_data, orient='index', columns=table_header[1:]) 
df=df.reset_index().rename(columns={'index':table_header[0]})
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Not assigned
# 5                                     Islington Avenue
# 6                                       Rouge, Malvern
# 7                                      Don Mills North
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 10                                           Glencairn
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12              Highland Creek, Rouge Hill, Port Union
# 13                    Flemingdon Park, Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90                                     L'Amoreaux West
# 91                                            Rosedale
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
# [103 rows x 3 columns]

# %% [markdown]
# Print the shape of the data frame

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Part 2: Get Latitude and Longitude for postal codes

# %% [markdown]
# Import required libraries

# %%
import numpy as np

# %% [markdown]
# Read the csv file given in assignment into a dataframe

# %%
path='http://cocl.us/Geospatial_data'
df_ll = pd.read_csv(path)
df_ll.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Add two new columns - one for latitude and one for longitude to our dataframe that contains postal code - neighbourhood details and initialize them with NaN

# %%
df['Latitude'] = np.NaN
df['Longitude'] = np.NaN

# %% [markdown]
# For each row in the dataframe containing the postal code - neigbourhood details, extract the postal code. Find the postal code in the second data frame which contains the postal code - latitude, longitude information. Extract the latitude and longitude corresponding to the postal code. While extracting the latitude, longitude information, ensure that there is one and only one entry for the corresponding postal code in the second data frame. If not, reset the latitude and longitude information to NaN. Update the latitude, longitude information in the first data frame against the row corresponding to the postal index

# %%
for index, row in df.iterrows():
    postal_code=row['Postcode']
    LL_info=df_ll[df_ll['Postal Code'] == postal_code]
    
    if LL_info.shape[0] == 1:
        latitude=LL_info.iloc[0]['Latitude']
        longitude=LL_info.iloc[0]['Longitude'] 
    else:
        latitude=np.NaN
        longitude=np.NaN
        
    df.at[index, 'Latitude']  = latitude
    df.at[index, 'Longitude'] = longitude

# %% [markdown]
# Print the data frame and check that the updates are as expected and that all rows has valid data for all columns

# %%
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Not assigned  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# ## Part 3: Clustering Neighbourhoods

# %% [markdown]
# Import required libraries

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

from sklearn.cluster import KMeans

import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# Print the boroughs

# %%
print(df['Borough'].unique())
# Out:
# ['North York' 'Downtown Toronto' "Queen's Park" 'Etobicoke' 'Scarborough'
#  'East York' 'York' 'East Toronto' 'West Toronto' 'Central Toronto'
#  'Mississauga']

# %% [markdown]
# To simplify the problem, we look at the neigbourhood of boroughs that contain 'Toronto'. Extract boroughs that contain 'Toronto' in a new data frame called toronto_data

# %%
toronto_data=df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
toronto_data
# Out:
#    Postcode           Borough  \
# 0       M5A  Downtown Toronto
# 1       M5B  Downtown Toronto
# 2       M5C  Downtown Toronto
# 3       M4E      East Toronto
# 4       M5E  Downtown Toronto
# 5       M5G  Downtown Toronto
# 6       M6G  Downtown Toronto
# 7       M5H  Downtown Toronto
# 8       M6H      West Toronto
# 9       M5J  Downtown Toronto
# 10      M6J      West Toronto
# 11      M4K      East Toronto
# 12      M5K  Downtown Toronto
# 13      M6K      West Toronto
# 14      M4L      East Toronto
# 15      M5L  Downtown Toronto
# 16      M4M      East Toronto
# 17      M4N   Central Toronto
# 18      M5N   Central Toronto
# 19      M4P   Central Toronto
# 20      M5P   Central Toronto
# 21      M6P      West Toronto
# 22      M4R   Central Toronto
# 23      M5R   Central Toronto
# 24      M6R      West Toronto
# 25      M4S   Central Toronto
# 26      M5S  Downtown Toronto
# 27      M6S      West Toronto
# 28      M4T   Central Toronto
# 29      M5T  Downtown Toronto
# 30      M4V   Central Toronto
# 31      M5V  Downtown Toronto
# 32      M4W  Downtown Toronto
# 33      M5W  Downtown Toronto
# 34      M4X  Downtown Toronto
# 35      M5X  Downtown Toronto
# 36      M4Y  Downtown Toronto
# 37      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                           Harbourfront, Regent Park  43.654260 -79.360636
# 1                            Ryerson, Garden District  43.657162 -79.378937
# 2                                      St. James Town  43.651494 -79.375418
# 3                                         The Beaches  43.676357 -79.293031
# 4                                         Berczy Park  43.644771 -79.373306
# 5                                  Central Bay Street  43.657952 -79.387383
# 6                                            Christie  43.669542 -79.422564
# 7                            Adelaide, King, Richmond  43.650571 -79.384568
# 8                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 9   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 10                           Little Portugal, Trinity  43.647927 -79.419750
# 11                       The Danforth West, Riverdale  43.679557 -79.352188
# 12           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 13       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 14                     The Beaches West, India Bazaar  43.668999 -79.315572
# 15                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 16                                    Studio District  43.659526 -79.340923
# 17                                      Lawrence Park  43.728020 -79.388790
# 18                                           Roselawn  43.711695 -79.416936
# 19                                   Davisville North  43.712751 -79.390197
# 20                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 21                      High Park, The Junction South  43.661608 -79.464763
# 22                                 North Toronto West  43.715383 -79.405678
# 23                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 24                             Parkdale, Roncesvalles  43.648960 -79.456325
# 25                                         Davisville  43.704324 -79.388790
# 26                     Harbord, University of Toronto  43.662696 -79.400049
# 27                                 Runnymede, Swansea  43.651571 -79.484450
# 28                        Moore Park, Summerhill East  43.689574 -79.383160
# 29          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 30  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 31  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 32                                           Rosedale  43.679563 -79.377529
# 33                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 34                        Cabbagetown, St. James Town  43.667967 -79.367675
# 35             First Canadian Place, Underground city  43.648429 -79.382280
# 36                               Church and Wellesley  43.665860 -79.383160
# 37  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %% [markdown]
# Get the latitude, longitude for the city of Toronto, Canada

# %%
address = 'Toronto, CAN'

geolocator = Nominatim(user_agent="can_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6913544, -79.5006666.

# %% [markdown]
# Visualize the toronto neighbourhood in a map

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Define four square credentials

# %%
CLIENT_ID = 'XXX'
CLIENT_SECRET = 'YYY' 
VERSION = '20180605' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0OUEGH5DZVMBOKZL5NEEXPMBK42XH2EEPXUHBVVSQPLS3QM5
# CLIENT_SECRET:45VSVB5TJYWEKUN3JOSE10E5QLCUU32WVE5EMZQZPVSP1RTC

# %% [markdown]
# Get 100 nearby venues (within the radius of 500) for each neigbourhood to use as feature for clustering of neighbourhood

# %%
venues_list=[]
for lat, lng, neighbourhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighbourhood']):
     
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, 500, 100)
            
       
    results = requests.get(url).json()["response"]['groups'][0]['items']
    for item in results:
        venues_list.append((neighbourhood, lat, lng, 
                            item['venue']['name'], item['venue']['location']['lat'], item['venue']['location']['lng'], item['venue']['categories'][0]['name']))
                        
    # print(venues_list)
    
    toronto_venues = pd.DataFrame([item for item in venues_list])
    toronto_venues.columns = ['Neighbourhood', 'Neighbourhood Latitude', 'Neighbourhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']

# %%
print("No of venues for Toronto neighbourhood:", toronto_venues.shape[0])
print("No of categories of venues for Toronto neighbourhood:", len(toronto_venues['Venue Category'].unique()))
# Out:
# No of venues for Toronto neighbourhood: 1688
# No of categories of venues for Toronto neighbourhood: 235

# %% [markdown]
# Across all neigbourhoods of Toronto, we have 1688 venues which falls within 235 category. We want to find for each of the 38 neighbourhoods of Toronto, the top 5 category of venues that exists in the neighbourhood

# %%
toronto_venue_category_onehot = pd.get_dummies(toronto_venues[['Venue Category']])                        
toronto_venue_onehot = pd.merge(toronto_venues['Neighbourhood'], toronto_venue_category_onehot, left_index=True, right_index=True)
toronto_venues_grouped = toronto_venue_onehot.groupby('Neighbourhood').mean().reset_index()

# %%
print("No of entries for venues after one-hot:", toronto_venue_onehot.shape[0])
print("No of entries for venues after neighbourhood grouping for category:", toronto_venues_grouped.shape)
# Out:
# No of entries for venues after one-hot: 1688
# No of entries for venues after neighbourhood grouping for category: (38, 236)

# %% [markdown]
# Run K-mens clustering with K=4

# %%
toronto_venues_grouped_clustering = toronto_venues_grouped.drop('Neighbourhood', 1)
kmeans = KMeans(n_clusters=4, random_state=0).fit(toronto_venues_grouped_clustering)
kmeans.labels_
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2,
#        1, 2, 1, 2, 2, 1, 3, 2, 2, 2, 2, 2, 2, 0, 2, 2], dtype=int32)

# %% [markdown]
# We now have for each of the neighbourhood, the occurence count for each venue category. Find the top 5 for each neighbourhood. Also update the resultant data frame with cluster information

# %%
toronto_nbhood_cluster_top5 = []

for index, row in toronto_venues_grouped.iterrows():
    neighbourhood = row['Neighbourhood']
    row_transpose  = toronto_venues_grouped[toronto_venues_grouped['Neighbourhood'] == neighbourhood].T.reset_index()
    row_categories = row_transpose.iloc[1:]
    row_categories.columns=['Venue Category', 'Freq']
    row_categories.set_index('Venue Category', inplace=True)
    row_categories_sorted = row_categories.sort_values('Freq', ascending=False)
    row_categories_top5=row_categories_sorted.index.values[0:5]
    
    toronto_data_row = toronto_data[toronto_data['Neighbourhood'] == neighbourhood]
    neighbourhood_top5=[neighbourhood, toronto_data_row.iloc[0]['Latitude'], toronto_data_row.iloc[0]['Longitude'], kmeans.labels_[index]]
    for item in row_categories_top5:
        neighbourhood_top5.append(item)
        
    toronto_nbhood_cluster_top5.append(neighbourhood_top5)

# print(toronto_nbhood_cluster_top5)

# %% [markdown]
# Covert the list to pandas data frame and print to check if it looks good

# %%
df_nbhood_venue=pd.DataFrame.from_records(toronto_nbhood_cluster_top5) 
df_nbhood_venue.columns=['Neighbourhood', 'Latitude', 'Longitude','Cluster', '1st Venue Category', '2nd Venue Category', '3rd Venue Category', '4th Venue Category', '5th Venue Category']
df_nbhood_venue
# Out:
#                                         Neighbourhood   Latitude  Longitude  \
# 0                            Adelaide, King, Richmond  43.650571 -79.384568
# 1                                         Berczy Park  43.644771 -79.373306
# 2        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 3   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 5                         Cabbagetown, St. James Town  43.667967 -79.367675
# 6                                  Central Bay Street  43.657952 -79.387383
# 7           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 8                                            Christie  43.669542 -79.422564
# 9                                Church and Wellesley  43.665860 -79.383160
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                                         Davisville  43.704324 -79.388790
# 12                                   Davisville North  43.712751 -79.390197
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 14           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 15                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 16             First Canadian Place, Underground city  43.648429 -79.382280
# 17                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 18                     Harbord, University of Toronto  43.662696 -79.400049
# 19  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 20                          Harbourfront, Regent Park  43.654260 -79.360636
# 21                      High Park, The Junction South  43.661608 -79.464763
# 22                                      Lawrence Park  43.728020 -79.388790
# 23                           Little Portugal, Trinity  43.647927 -79.419750
# 24                        Moore Park, Summerhill East  43.689574 -79.383160
# 25                                 North Toronto West  43.715383 -79.405678
# 26                             Parkdale, Roncesvalles  43.648960 -79.456325
# 27                                           Rosedale  43.679563 -79.377529
# 28                                           Roselawn  43.711695 -79.416936
# 29                                 Runnymede, Swansea  43.651571 -79.484450
# 30                           Ryerson, Garden District  43.657162 -79.378937
# 31                                     St. James Town  43.651494 -79.375418
# 32                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 33                                    Studio District  43.659526 -79.340923
# 34                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 35                                        The Beaches  43.676357 -79.293031
# 36                     The Beaches West, India Bazaar  43.668999 -79.315572
# 37                       The Danforth West, Riverdale  43.679557 -79.352188
#
#     Cluster                  1st Venue Category  \
# 0         2          Venue Category_Coffee Shop
# 1         2          Venue Category_Coffee Shop
# 2         2       Venue Category_Breakfast Spot
# 3         2   Venue Category_Light Rail Station
# 4         2      Venue Category_Airport Service
# 5         2          Venue Category_Coffee Shop
# 6         2          Venue Category_Coffee Shop
# 7         2                 Venue Category_Café
# 8         2                 Venue Category_Café
# 9         2          Venue Category_Coffee Shop
# 10        2          Venue Category_Coffee Shop
# 11        2         Venue Category_Dessert Shop
# 12        2                Venue Category_Hotel
# 13        2   Venue Category_Light Rail Station
# 14        2          Venue Category_Coffee Shop
# 15        2               Venue Category_Bakery
# 16        2          Venue Category_Coffee Shop
# 17        1        Venue Category_Jewelry Store
# 18        2                 Venue Category_Café
# 19        2          Venue Category_Coffee Shop
# 20        2          Venue Category_Coffee Shop
# 21        2                 Venue Category_Café
# 22        1             Venue Category_Bus Line
# 23        2                  Venue Category_Bar
# 24        1           Venue Category_Playground
# 25        2  Venue Category_Sporting Goods Shop
# 26        2            Venue Category_Gift Shop
# 27        1                 Venue Category_Park
# 28        3               Venue Category_Garden
# 29        2                 Venue Category_Café
# 30        2          Venue Category_Coffee Shop
# 31        2                 Venue Category_Café
# 32        2          Venue Category_Coffee Shop
# 33        2                 Venue Category_Café
# 34        2                 Venue Category_Café
# 35        0                Venue Category_Trail
# 36        2       Venue Category_Sandwich Place
# 37        2     Venue Category_Greek Restaurant
#
#                               2nd Venue Category  \
# 0                            Venue Category_Café
# 1                    Venue Category_Cocktail Bar
# 2                            Venue Category_Café
# 3                     Venue Category_Yoga Studio
# 4                  Venue Category_Airport Lounge
# 5                      Venue Category_Restaurant
# 6                  Venue Category_Ice Cream Shop
# 7   Venue Category_Vegetarian / Vegan Restaurant
# 8                   Venue Category_Grocery Store
# 9             Venue Category_Japanese Restaurant
# 10                          Venue Category_Hotel
# 11                    Venue Category_Pizza Place
# 12                            Venue Category_Gym
# 13                            Venue Category_Pub
# 14                           Venue Category_Café
# 15                       Venue Category_Pharmacy
# 16                           Venue Category_Café
# 17                       Venue Category_Bus Line
# 18                      Venue Category_Bookstore
# 19                          Venue Category_Hotel
# 20                            Venue Category_Pub
# 21             Venue Category_Mexican Restaurant
# 22                           Venue Category_Park
# 23                    Venue Category_Coffee Shop
# 24                     Venue Category_Restaurant
# 25                    Venue Category_Coffee Shop
# 26                 Venue Category_Breakfast Spot
# 27                     Venue Category_Playground
# 28              Venue Category_Afghan Restaurant
# 29                    Venue Category_Coffee Shop
# 30                 Venue Category_Clothing Store
# 31                    Venue Category_Coffee Shop
# 32                           Venue Category_Café
# 33                    Venue Category_Coffee Shop
# 34                 Venue Category_Sandwich Place
# 35                   Venue Category_Neighborhood
# 36                           Venue Category_Park
# 37                    Venue Category_Coffee Shop
#
#                          3rd Venue Category  \
# 0                 Venue Category_Steakhouse
# 1             Venue Category_Farmers Market
# 2                Venue Category_Coffee Shop
# 3                       Venue Category_Park
# 4           Venue Category_Airport Terminal
# 5                Venue Category_Pizza Place
# 6         Venue Category_Italian Restaurant
# 7         Venue Category_Chinese Restaurant
# 8                       Venue Category_Park
# 9           Venue Category_Sushi Restaurant
# 10                      Venue Category_Café
# 11            Venue Category_Sandwich Place
# 12                      Venue Category_Park
# 13               Venue Category_Coffee Shop
# 14                     Venue Category_Hotel
# 15               Venue Category_Supermarket
# 16                     Venue Category_Hotel
# 17                     Venue Category_Trail
# 18       Venue Category_Japanese Restaurant
# 19                  Venue Category_Aquarium
# 20                      Venue Category_Café
# 21                       Venue Category_Bar
# 22               Venue Category_Swim School
# 23          Venue Category_Asian Restaurant
# 24              Venue Category_Tennis Court
# 25               Venue Category_Yoga Studio
# 26                   Venue Category_Dog Run
# 27                  Venue Category_Building
# 28  Venue Category_Mediterranean Restaurant
# 29          Venue Category_Sushi Restaurant
# 30            Venue Category_Cosmetics Shop
# 31                     Venue Category_Hotel
# 32                Venue Category_Restaurant
# 33        Venue Category_Italian Restaurant
# 34               Venue Category_Coffee Shop
# 35         Venue Category_Health Food Store
# 36                   Venue Category_Brewery
# 37        Venue Category_Italian Restaurant
#
#                           4th Venue Category  \
# 0                         Venue Category_Bar
# 1                        Venue Category_Café
# 2               Venue Category_Burrito Place
# 3                  Venue Category_Comic Shop
# 4            Venue Category_Sculpture Garden
# 5                      Venue Category_Bakery
# 6                        Venue Category_Café
# 7                      Venue Category_Bakery
# 8                  Venue Category_Baby Store
# 9                  Venue Category_Restaurant
# 10                 Venue Category_Restaurant
# 11                Venue Category_Coffee Shop
# 12             Venue Category_Clothing Store
# 13           Venue Category_Sushi Restaurant
# 14                 Venue Category_Restaurant
# 15                       Venue Category_Park
# 16                 Venue Category_Restaurant
# 17           Venue Category_Sushi Restaurant
# 18                        Venue Category_Bar
# 19         Venue Category_Italian Restaurant
# 20                     Venue Category_Bakery
# 21            Venue Category_Thai Restaurant
# 22          Venue Category_Afghan Restaurant
# 23    Venue Category_New American Restaurant
# 24                  Venue Category_Nightclub
# 25                 Venue Category_Restaurant
# 26                        Venue Category_Bar
# 27                      Venue Category_Trail
# 28         Venue Category_Mexican Restaurant
# 29         Venue Category_Italian Restaurant
# 30  Venue Category_Middle Eastern Restaurant
# 31         Venue Category_Italian Restaurant
# 32               Venue Category_Cocktail Bar
# 33        Venue Category_American Restaurant
# 34                Venue Category_Pizza Place
# 35                        Venue Category_Pub
# 36               Venue Category_Burger Joint
# 37             Venue Category_Ice Cream Shop
#
#                           5th Venue Category
# 0             Venue Category_Thai Restaurant
# 1                 Venue Category_Cheese Shop
# 2                         Venue Category_Bar
# 3            Venue Category_Recording Studio
# 4          Venue Category_Airport Food Court
# 5                         Venue Category_Pub
# 6                Venue Category_Burger Joint
# 7          Venue Category_Mexican Restaurant
# 8          Venue Category_Athletics & Sports
# 9                     Venue Category_Gay Bar
# 10        Venue Category_American Restaurant
# 11           Venue Category_Sushi Restaurant
# 12             Venue Category_Sandwich Place
# 13                 Venue Category_Bagel Shop
# 14                     Venue Category_Bakery
# 15       Venue Category_Gym / Fitness Center
# 16                 Venue Category_Steakhouse
# 17          Venue Category_Afghan Restaurant
# 18                     Venue Category_Bakery
# 19                       Venue Category_Café
# 20                       Venue Category_Park
# 21        Venue Category_Fried Chicken Joint
# 22    Venue Category_New American Restaurant
# 23                 Venue Category_Restaurant
# 24         Venue Category_Mexican Restaurant
# 25         Venue Category_Miscellaneous Shop
# 26                       Venue Category_Bank
# 27          Venue Category_Afghan Restaurant
# 28  Venue Category_Middle Eastern Restaurant
# 29                  Venue Category_Bookstore
# 30                       Venue Category_Café
# 31                 Venue Category_Restaurant
# 32         Venue Category_Seafood Restaurant
# 33                     Venue Category_Bakery
# 34                        Venue Category_Pub
# 35        Venue Category_Monument / Landmark
# 36          Venue Category_Food & Drink Shop
# 37     Venue Category_Furniture / Home Store

# %% [markdown]
# We see that the cluster 1 has more establishments of parks, playgrounds or nature trails. Cluster 2 includes neighbourhood that has high food establishments such as coffee, restaurants or bub. While we cannot be too sure of cluster 0 and 3 due to low sample points in the cluster, it looks cluster 0 is most likely to be a tourist place with high establishments of trails and monuments/Landmark. We can plot the neighbourhoods based on cluster to visualize the analysis

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)


colors = ['red', 'green', 'blue', 'purple']

markers_colors = []
for lat, lon, poi, cluster in zip(df_nbhood_venue['Latitude'], df_nbhood_venue['Longitude'], df_nbhood_venue['Neighbourhood'], df_nbhood_venue['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=colors[cluster-1],
        fill=True,
        fill_color=colors[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# That concludes our analysis of clustering of neighbourhood of Toronto!
